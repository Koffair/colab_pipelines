# %% [markdown]
# # Preparing data
#
# <a target="_blank" href="https://colab.research.google.com/github/Koffair/colab_pipelines/blob/main/notebooks/prepare_data.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # REFACTOR IT
# - put floret training into a separate ipynb
# - add data cleaning and preparation code
# # Floret model training
# An attempt to train a [floret](https://github.com/explosion/floret) model using the [OSCAR 2019](https://oscar-project.org/post/oscar-2019/) corpus.
#
# ## WARNING
# Thins Notebook assumes that you have downloaded the appropriate OSCAR sub-corpus and it is accessible from your Google Drive.
#
# ## Setting up the environment
# ### floret

# %%
# !git clone https://github.com/explosion/floret
# Out:
# fatal: destination path 'floret' already exists and is not an empty directory.
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !cd floret; make
# Out:
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/args.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/autotune.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/matrix.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/dictionary.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/MurmurHash3.cpp
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/loss.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/productquantizer.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/densematrix.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/quantmatrix.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/vector.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/model.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/utils.cc
# c++ -pthread -std=c++11 -O3 -funroll-loops -DNDEBUG -c src/meter.cc
# ...

# %% [markdown]
# ### Connecting to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/"
# Out:
# 'Copy of floret.ipynb'	 floret_training_colab_version.ipynb
#  corpora		 mcc_langmods

# %% [markdown]
# Uncompress OSCAR txt files

# %%
# !cd "/content/gdrive/My Drive/Colab Notebooks/corpora/OSCAR2019_hu"; gzip -d *.gz

# %% [markdown]
# Uncompress Common Voice data

# %%
# !cd "/content/gdrive/My Drive/Colab Notebooks/corpora/common_voice/2023_02_16"; tar -xvf cv-corpus-12.0-2022-12-07-hu.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562375.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562414.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562415.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562416.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562417.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562418.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562444.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562445.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562446.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562447.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562448.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562573.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562574.mp3
# cv-corpus-12.0-2022-12-07/hu/clips/common_voice_hu_26562575.mp3
# ...

# %% [markdown]
# Uncompress nyest corpus

# %%
# !cd "/content/gdrive/My Drive/Colab Notebooks/corpora/nyest"; unzip contents.zip
# Out:
# Archive:  contents.zip
#   inflating: contents.csv

# %% [markdown]
# **#TODO**
#
#
# 1.   Unzip corpora files
# 2.   Clean up -> code on laptop
# 3.   Merge OSCAR2019 & nyest
# 4.   Train it baby

# %% [markdown]
# ## Train the model
